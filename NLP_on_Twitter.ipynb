# %% [markdown]
# <a href="https://colab.research.google.com/github/annuusshha/NLP-Twitter/blob/main/NLP_on_Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-39d150af-68d5-4d88-9a1a-80d3e6bffdb1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39d150af-68d5-4d88-9a1a-80d3e6bffdb1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %% [markdown]
# a) Uploading dataset and removing unnecessary punctuations from tweet

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

data=pd.read_csv('train.csv') 
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)   
    return input_txt  

data['new'] = np.vectorize(remove_pattern)(data['tweet'], "@[\w]*")
data.head()
# Out:
#    id  ...                                                new
# 0   1  ...    when a father is dysfunctional and is so sel...
# 1   2  ...    thanks for #lyft credit i can't use cause th...
# 2   3  ...                                bihday your majesty
# 3   4  ...  #model   i love u take with u all the time in ...
# 4   5  ...             factsguide: society now    #motivation
#
# [5 rows x 4 columns]

# %% [markdown]
# b) Replacing punctuations

# %%
data['new'] = data['new'].str.replace("[^a-zA-Z#]", " ")
data.head()
# Out:
#    id  ...                                                new
# 0   1  ...    when a father is dysfunctional and is so sel...
# 1   2  ...    thanks for #lyft credit i can t use cause th...
# 2   3  ...                                bihday your majesty
# 3   4  ...  #model   i love u take with u all the time in ...
# 4   5  ...             factsguide  society now    #motivation
#
# [5 rows x 4 columns]

# %% [markdown]
# c) Removing stopwords (words that doesn't add much meaning)

# %%
data['new'] = data['new'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
data.head()
# Out:
#    id  ...                                                new
# 0   1  ...  when father dysfunctional selfish drags kids i...
# 1   2  ...  thanks #lyft credit cause they offer wheelchai...
# 2   3  ...                                bihday your majesty
# 3   4  ...                         #model love take with time
# 4   5  ...                     factsguide society #motivation
#
# [5 rows x 4 columns]

# %% [markdown]
# d) Tokenization - Splitting Words

# %%
tokenized_tweet = data['new'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0    [when, father, dysfunctional, selfish, drags, ...
# 1    [thanks, #lyft, credit, cause, they, offer, wh...
# 2                              [bihday, your, majesty]
# 3                     [#model, love, take, with, time]
# 4                   [factsguide, society, #motivation]
# Name: new, dtype: object

# %% [markdown]
# e) Joining tokenized words together

# %%
all_words = ' '.join([text for text in data['new']])
all_words
# Out:
